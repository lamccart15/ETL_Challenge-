# %%
# Set dependencies
import pandas as pd
from sqlalchemy import create_engine

# %%
# Read in CSV files 
csv_file = "Olympic_Medal_Dataset.csv"
olympic_medal_df = pd.read_csv(csv_file)
olympic_medal_df.head()
# Out:
#              Team(IOC Code)  summer_rank s_gold  s_silver  s_bronze  \
# 0         Afghanistan (AFG)           14      0         0         2
# 1             Algeria (ALG)           13      5         4         8
# 2           Argentina (ARG)           24     21        25        28
# 3             Armenia (ARM)            6      2         6         6
# 4   Australasia (ANZ) [ANZ]            2      3         4         5
#
#   summer_total  winter_rank  w_gold  w_silver  w_bronze  winter_total  \
# 0            2            0       0         0         0             0
# 1           17            3       0         0         0             0
# 2           74           19       0         0         0             0
# 3           14            7       0         0         0             0
# 4           12            0       0         0         0             0
#
#    overall_rank total_gold  total_silver  total_bronze total_medals
# 0            14          0             0             2            2
# 1            16          5             4             8           17
# 2            43         21            25            28           74
# 3            13          2             6             6           14
# 4             2          3             4             5           12

# %%
# Rename column
olympic_medal_df.rename(columns={"Team(IOC Code)": "Country(Country Code)"}, inplace=True)
olympic_medal_df.head()
# Out:
#       Country(Country Code)  summer_rank s_gold  s_silver  s_bronze  \
# 0         Afghanistan (AFG)           14      0         0         2
# 1             Algeria (ALG)           13      5         4         8
# 2           Argentina (ARG)           24     21        25        28
# 3             Armenia (ARM)            6      2         6         6
# 4   Australasia (ANZ) [ANZ]            2      3         4         5
#
#   summer_total  winter_rank  w_gold  w_silver  w_bronze  winter_total  \
# 0            2            0       0         0         0             0
# 1           17            3       0         0         0             0
# 2           74           19       0         0         0             0
# 3           14            7       0         0         0             0
# 4           12            0       0         0         0             0
#
#    overall_rank total_gold  total_silver  total_bronze total_medals
# 0            14          0             0             2            2
# 1            16          5             4             8           17
# 2            43         21            25            28           74
# 3            13          2             6             6           14
# 4             2          3             4             5           12

# %%
# Split Column into Country and Country Code columns 
cleaned_olympic_medal_df = olympic_medal_df["Country(Country Code)"].str.strip().str.split(pat="\s", expand=True)[[0,1]]
cleaned_olympic_medal_df.head()
# Out:
#              0      1
# 0  Afghanistan  (AFG)
# 1      Algeria  (ALG)
# 2    Argentina  (ARG)
# 3      Armenia  (ARM)
# 4  Australasia  (ANZ)

# %%
# Add new columns to dataframe
country = cleaned_olympic_medal_df[0]
olympic_medal_df["Country"] = country
olympic_medal_df.head()
# Out:
#       Country(Country Code)  summer_rank s_gold  s_silver  s_bronze  \
# 0         Afghanistan (AFG)           14      0         0         2
# 1             Algeria (ALG)           13      5         4         8
# 2           Argentina (ARG)           24     21        25        28
# 3             Armenia (ARM)            6      2         6         6
# 4   Australasia (ANZ) [ANZ]            2      3         4         5
#
#   summer_total  winter_rank  w_gold  w_silver  w_bronze  winter_total  \
# 0            2            0       0         0         0             0
# 1           17            3       0         0         0             0
# 2           74           19       0         0         0             0
# 3           14            7       0         0         0             0
# 4           12            0       0         0         0             0
#
#    overall_rank total_gold  total_silver  total_bronze total_medals  \
# 0            14          0             0             2            2
# 1            16          5             4             8           17
# 2            43         21            25            28           74
# 3            13          2             6             6           14
# 4             2          3             4             5           12
#
#        Country
# 0  Afghanistan
# 1      Algeria
# 2    Argentina
# 3      Armenia
# 4  Australasia

# %%
olympic_medal_df=olympic_medal_df[["Country", "summer_rank", "s_gold", "s_silver", "s_bronze", "summer_total", "winter_rank", "w_gold", "w_silver", "w_bronze", "winter_total", "overall_rank", "total_gold", "total_silver", "total_bronze", "total_medals"]]
olympic_medal_df.head()
# Out:
#        Country  summer_rank s_gold  s_silver  s_bronze summer_total  \
# 0  Afghanistan           14      0         0         2            2
# 1      Algeria           13      5         4         8           17
# 2    Argentina           24     21        25        28           74
# 3      Armenia            6      2         6         6           14
# 4  Australasia            2      3         4         5           12
#
#    winter_rank  w_gold  w_silver  w_bronze  winter_total  overall_rank  \
# 0            0       0         0         0             0            14
# 1            3       0         0         0             0            16
# 2           19       0         0         0             0            43
# 3            7       0         0         0             0            13
# 4            0       0         0         0             0             2
#
#   total_gold  total_silver  total_bronze total_medals
# 0          0             0             2            2
# 1          5             4             8           17
# 2         21            25            28           74
# 3          2             6             6           14
# 4          3             4             5           12

# %%
# Read in CSV files 
csv_file = "Olympic_ Medal_Dictionary.csv"
country_information_df = pd.read_csv(csv_file)
country_information_df.head()
# Out:
#            Country Code  Population  GDP per Capita
# 0      Afghanistan  AFG  32526562.0      594.323081
# 1          Albania  ALB   2889167.0     3945.217582
# 2          Algeria  ALG  39666519.0     4206.031232
# 3  American Samoa*  ASA     55538.0             NaN
# 4          Andorra  AND     70473.0             NaN

# %%
# Drop empty rows from country information database 
country_information_df.dropna(inplace=True)
country_information_df.head()
# Out:
#                Country Code  Population  GDP per Capita
# 0          Afghanistan  AFG  32526562.0      594.323081
# 1              Albania  ALB   2889167.0     3945.217582
# 2              Algeria  ALG  39666519.0     4206.031232
# 5               Angola  ANG  25021974.0     4101.472152
# 6  Antigua and Barbuda  ANT     91818.0    13714.731962

# %%
# Connect to local database
rds_connection_string = "postgres:postgres@localhost:5432/olympic_medals"
engine = create_engine(f'postgresql://{rds_connection_string}')

# %%
# Check table names
engine.table_names()
# Out:
# ['country_information', 'olympic_medals']

# %%
# Load country dataframe into database 
country_information_df.to_sql(name='country_information', con=engine, if_exists='append', index=False)
# Out:
# ---------------------------------------------------------------------------
# UndefinedColumn                           Traceback (most recent call last)
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1257                     self.dialect.do_executemany(
# -> 1258                         cursor, statement, parameters, context
#    1259                     )
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\dialects\postgresql\psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     872         if self.executemany_mode is EXECUTEMANY_DEFAULT:
# --> 873             cursor.executemany(statement, parameters)
#     874             return
#
# UndefinedColumn: column "Country" of relation "country_information" does not exist
# LINE 1: INSERT INTO country_information ("Country", "Code", "Populat...
#                                          ^
#
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# <ipython-input-29-ea9ec2c64365> in <module>
# ----> 1 country_information_df.to_sql(name='country_information', con=engine, if_exists='append', index=False)
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2661             chunksize=chunksize,
#    2662             dtype=dtype,
# -> 2663             method=method,
#    2664         )
#    2665
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\io\sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#     519         chunksize=chunksize,
#     520         dtype=dtype,
# --> 521         method=method,
#     522     )
#     523
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\io\sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)
#    1315         )
#    1316         table.create()
# -> 1317         table.insert(chunksize, method=method)
#    1318         if not name.isdigit() and not name.islower():
#    1319             # check for potentially case sensitivity issues (GH7815)
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\io\sql.py in insert(self, chunksize, method)
#     753
#     754                 chunk_iter = zip(*[arr[start_i:end_i] for arr in data_list])
# --> 755                 exec_insert(conn, keys, chunk_iter)
#     756
#     757     def _query_iterator(
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\io\sql.py in _execute_insert(self, conn, keys, data_iter)
#     667         """
#     668         data = [dict(zip(keys, row)) for row in data_iter]
# --> 669         conn.execute(self.table.insert(), data)
#     670
#     671     def _execute_insert_multi(self, conn, keys, data_iter):
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in execute(self, object_, *multiparams, **params)
#    1012             )
#    1013         else:
# -> 1014             return meth(self, multiparams, params)
#    1015
#    1016     def _execute_function(self, func, multiparams, params):
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\sql\elements.py in _execute_on_connection(self, connection, multiparams, params)
#     296     def _execute_on_connection(self, connection, multiparams, params):
#     297         if self.supports_execution:
# --> 298             return connection._execute_clauseelement(self, multiparams, params)
#     299         else:
#     300             raise exc.ObjectNotExecutableError(self)
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _execute_clauseelement(self, elem, multiparams, params)
#    1131             distilled_params,
#    1132             compiled_sql,
# -> 1133             distilled_params,
#    1134         )
#    1135         if self._has_events or self.engine._has_events:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1316         except BaseException as e:
#    1317             self._handle_dbapi_exception(
# -> 1318                 e, statement, parameters, cursor, context
#    1319             )
#    1320
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1510             elif should_wrap:
#    1511                 util.raise_(
# -> 1512                     sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    1513                 )
#    1514             else:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     176
#     177         try:
# --> 178             raise exception
#     179         finally:
#     180             # credit to
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1256                 if not evt_handled:
#    1257                     self.dialect.do_executemany(
# -> 1258                         cursor, statement, parameters, context
#    1259                     )
#    1260             elif not parameters and context.no_parameters:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\dialects\postgresql\psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     871     def do_executemany(self, cursor, statement, parameters, context=None):
#     872         if self.executemany_mode is EXECUTEMANY_DEFAULT:
# --> 873             cursor.executemany(statement, parameters)
#     874             return
#     875
#
# ProgrammingError: (psycopg2.errors.UndefinedColumn) column "Country" of relation "country_information" does not exist
# LINE 1: INSERT INTO country_information ("Country", "Code", "Populat...
#                                          ^
#
# [SQL: INSERT INTO country_information ("Country", "Code", "Population", "GDP per Capita") VALUES (%(Country)s, %(Code)s, %(Population)s, %(GDP per Capita)s)]
# [parameters: ({'Country': 'Afghanistan', 'Code': 'AFG', 'Population': 32526562.0, 'GDP per Capita': 594.323081219966}, {'Country': 'Albania', 'Code': 'ALB', 'Population': 2889167.0, 'GDP per Capita': 3945.21758150914}, {'Country': 'Algeria', 'Code': 'ALG', 'Population': 39666519.0, 'GDP per Capita': 4206.03123244958}, {'Country': 'Angola', 'Code': 'ANG', 'Population': 25021974.0, 'GDP per Capita': 4101.47215182964}, {'Country': 'Antigua and Barbuda', 'Code': 'ANT', 'Population': 91818.0, 'GDP per Capita': 13714.731961698799}, {'Country': 'Argentina', 'Code': 'ARG', 'Population': 43416755.0, 'GDP per Capita': 13431.8783398577}, {'Country': 'Armenia', 'Code': 'ARM', 'Population': 3017712.0, 'GDP per Capita': 3489.12768956995}, {'Country': 'Australia', 'Code': 'AUS', 'Population': 23781169.0, 'GDP per Capita': 56310.9629933721}  ... displaying 10 of 176 total bound parameter sets ...  {'Country': 'Zambia', 'Code': 'ZAM', 'Population': 16211767.0, 'GDP per Capita': 1304.87901447726}, {'Country': 'Zimbabwe', 'Code': 'ZIM', 'Population': 15602751.0, 'GDP per Capita': 924.1438192534121})]
# (Background on this error at: http://sqlalche.me/e/13/f405)

# %%
# Load medals dataframe into database 
olympic_medal_df.to_sql(name='olympic_medals', con=engine, if_exists='append', index=False)
# Out:
# ---------------------------------------------------------------------------
# UndefinedColumn                           Traceback (most recent call last)
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1257                     self.dialect.do_executemany(
# -> 1258                         cursor, statement, parameters, context
#    1259                     )
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\dialects\postgresql\psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     872         if self.executemany_mode is EXECUTEMANY_DEFAULT:
# --> 873             cursor.executemany(statement, parameters)
#     874             return
#
# UndefinedColumn: column "Country" of relation "olympic_medals" does not exist
# LINE 1: INSERT INTO olympic_medals ("Country", summer_rank, s_gold, ...
#                                     ^
#
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# <ipython-input-30-15bcc4ca5cd3> in <module>
#       1 # Load medals dataframe into database
# ----> 2 olympic_medal_df.to_sql(name='olympic_medals', con=engine, if_exists='append', index=False)
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2661             chunksize=chunksize,
#    2662             dtype=dtype,
# -> 2663             method=method,
#    2664         )
#    2665
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\io\sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#     519         chunksize=chunksize,
#     520         dtype=dtype,
# --> 521         method=method,
#     522     )
#     523
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\io\sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)
#    1315         )
#    1316         table.create()
# -> 1317         table.insert(chunksize, method=method)
#    1318         if not name.isdigit() and not name.islower():
#    1319             # check for potentially case sensitivity issues (GH7815)
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\io\sql.py in insert(self, chunksize, method)
#     753
#     754                 chunk_iter = zip(*[arr[start_i:end_i] for arr in data_list])
# --> 755                 exec_insert(conn, keys, chunk_iter)
#     756
#     757     def _query_iterator(
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\io\sql.py in _execute_insert(self, conn, keys, data_iter)
#     667         """
#     668         data = [dict(zip(keys, row)) for row in data_iter]
# --> 669         conn.execute(self.table.insert(), data)
#     670
#     671     def _execute_insert_multi(self, conn, keys, data_iter):
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in execute(self, object_, *multiparams, **params)
#    1012             )
#    1013         else:
# -> 1014             return meth(self, multiparams, params)
#    1015
#    1016     def _execute_function(self, func, multiparams, params):
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\sql\elements.py in _execute_on_connection(self, connection, multiparams, params)
#     296     def _execute_on_connection(self, connection, multiparams, params):
#     297         if self.supports_execution:
# --> 298             return connection._execute_clauseelement(self, multiparams, params)
#     299         else:
#     300             raise exc.ObjectNotExecutableError(self)
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _execute_clauseelement(self, elem, multiparams, params)
#    1131             distilled_params,
#    1132             compiled_sql,
# -> 1133             distilled_params,
#    1134         )
#    1135         if self._has_events or self.engine._has_events:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1316         except BaseException as e:
#    1317             self._handle_dbapi_exception(
# -> 1318                 e, statement, parameters, cursor, context
#    1319             )
#    1320
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1510             elif should_wrap:
#    1511                 util.raise_(
# -> 1512                     sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    1513                 )
#    1514             else:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     176
#     177         try:
# --> 178             raise exception
#     179         finally:
#     180             # credit to
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1256                 if not evt_handled:
#    1257                     self.dialect.do_executemany(
# -> 1258                         cursor, statement, parameters, context
#    1259                     )
#    1260             elif not parameters and context.no_parameters:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\dialects\postgresql\psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     871     def do_executemany(self, cursor, statement, parameters, context=None):
#     872         if self.executemany_mode is EXECUTEMANY_DEFAULT:
# --> 873             cursor.executemany(statement, parameters)
#     874             return
#     875
#
# ProgrammingError: (psycopg2.errors.UndefinedColumn) column "Country" of relation "olympic_medals" does not exist
# LINE 1: INSERT INTO olympic_medals ("Country", summer_rank, s_gold, ...
#                                     ^
#
# [SQL: INSERT INTO olympic_medals ("Country", summer_rank, s_gold, s_silver, s_bronze, summer_total, winter_rank, w_gold, w_silver, w_bronze, winter_total, overall_rank, total_gold, total_silver, total_bronze, total_medals) VALUES (%(Country)s, %(summer_rank)s, %(s_gold)s, %(s_silver)s, %(s_bronze)s, %(summer_total)s, %(winter_rank)s, %(w_gold)s, %(w_silver)s, %(w_bronze)s, %(winter_total)s, %(overall_rank)s, %(total_gold)s, %(total_silver)s, %(total_bronze)s, %(total_medals)s)]
# [parameters: ({'Country': 'Afghanistan', 'summer_rank': 14, 's_gold': '0', 's_silver': 0, 's_bronze': 2, 'summer_total': '2', 'winter_rank': 0, 'w_gold': 0, 'w_silver': 0, 'w_bronze': 0, 'winter_total': 0, 'overall_rank': 14, 'total_gold': '0', 'total_silver': 0, 'total_bronze': 2, 'total_medals': '2'}, {'Country': 'Algeria', 'summer_rank': 13, 's_gold': '5', 's_silver': 4, 's_bronze': 8, 'summer_total': '17', 'winter_rank': 3, 'w_gold': 0, 'w_silver': 0, 'w_bronze': 0, 'winter_total': 0, 'overall_rank': 16, 'total_gold': '5', 'total_silver': 4, 'total_bronze': 8, 'total_medals': '17'}, {'Country': 'Argentina', 'summer_rank': 24, 's_gold': '21', 's_silver': 25, 's_bronze': 28, 'summer_total': '74', 'winter_rank': 19, 'w_gold': 0, 'w_silver': 0, 'w_bronze': 0, 'winter_total': 0, 'overall_rank': 43, 'total_gold': '21', 'total_silver': 25, 'total_bronze': 28, 'total_medals': '74'}, {'Country': 'Armenia', 'summer_rank': 6, 's_gold': '2', 's_silver': 6, 's_bronze': 6, 'summer_total': '14', 'winter_rank': 7, 'w_gold': 0, 'w_silver': 0, 'w_bronze': 0, 'winter_total': 0, 'overall_rank': 13, 'total_gold': '2', 'total_silver': 6, 'total_bronze': 6, 'total_medals': '14'}, {'Country': 'Australasia', 'summer_rank': 2, 's_gold': '3', 's_silver': 4, 's_bronze': 5, 'summer_total': '12', 'winter_rank': 0, 'w_gold': 0, 'w_silver': 0, 'w_bronze': 0, 'winter_total': 0, 'overall_rank': 2, 'total_gold': '3', 'total_silver': 4, 'total_bronze': 5, 'total_medals': '12'}, {'Country': 'Australia', 'summer_rank': 26, 's_gold': '147', 's_silver': 163, 's_bronze': 187, 'summer_total': '497', 'winter_rank': 19, 'w_gold': 5, 'w_silver': 5, 'w_bronze': 5, 'winter_total': 15, 'overall_rank': 45, 'total_gold': '152', 'total_silver': 168, 'total_bronze': 192, 'total_medals': '512'}, {'Country': 'Austria', 'summer_rank': 27, 's_gold': '18', 's_silver': 33, 's_bronze': 36, 'summer_total': '87', 'winter_rank': 23, 'w_gold': 64, 'w_silver': 81, 'w_bronze': 87, 'winter_total': 232, 'overall_rank': 50, 'total_gold': '82', 'total_silver': 114, 'total_bronze': 123, 'total_medals': '319'}, {'Country': 'Azerbaijan', 'summer_rank': 6, 's_gold': '7', 's_silver': 11, 's_bronze': 24, 'summer_total': '42', 'winter_rank': 6, 'w_gold': 0, 'w_silver': 0, 'w_bronze': 0, 'winter_total': 0, 'overall_rank': 12, 'total_gold': '7', 'total_silver': 11, 'total_bronze': 24, 'total_medals': '42'}  ... displaying 10 of 152 total bound parameter sets ...  {'Country': 'Independent', 'summer_rank': 1, 's_gold': '0', 's_silver': 1, 's_bronze': 2, 'summer_total': '3', 'winter_rank': 0, 'w_gold': 0, 'w_silver': 0, 'w_bronze': 0, 'winter_total': 0, 'overall_rank': 1, 'total_gold': '0', 'total_silver': 1, 'total_bronze': 2, 'total_medals': '3'}, {'Country': 'Mixed', 'summer_rank': 3, 's_gold': '8', 's_silver': 5, 's_bronze': 4, 'summer_total': '17', 'winter_rank': 0, 'w_gold': 0, 'w_silver': 0, 'w_bronze': 0, 'winter_total': 0, 'overall_rank': 3, 'total_gold': '8', 'total_silver': 5, 'total_bronze': 4, 'total_medals': '17'})]
# (Background on this error at: http://sqlalche.me/e/13/f405)
